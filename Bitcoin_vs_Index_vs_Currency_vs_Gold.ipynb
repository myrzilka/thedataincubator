# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('BTC2.csv')

# %%
df.head(10)
# Out:
#          Date   Open   High    Low  Close  Adj Close   Volume
# 0  2011-12-31  4.248  4.995  4.200  4.722      4.722   596240
# 1  2012-01-01  4.722  5.500  4.615  5.268      5.268   553045
# 2  2012-01-02  5.268  5.470  4.800  5.217      5.217   360357
# 3  2012-01-03  5.217  5.290  4.650  4.881      4.881   619170
# 4  2012-01-04  4.881  5.700  4.751  5.574      5.574   688717
# 5  2012-01-05  5.574  7.220  5.574  6.948      6.948  1130623
# 6  2012-01-06  6.948  7.210  6.126  6.697      6.697  1481327
# 7  2012-01-07  6.697  7.016  6.380  6.810      6.810   325053
# 8  2012-01-08  6.810  7.200  6.734  7.114      7.114   403151
# 9  2012-01-09  7.114  7.191  5.810  6.326      6.326   960592

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df1 = pd.read_csv('NASDQ.csv')

# %%
df1.head(10)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2012-01-03  2657.389893  2665.899902  2641.979980  2648.719971
# 1  2012-01-04  2639.899902  2653.179932  2627.229980  2648.360107
# 2  2012-01-05  2642.570068  2673.560059  2631.229980  2669.860107
# 3  2012-01-06  2671.169922  2682.120117  2658.830078  2674.219971
# 4  2012-01-09  2682.979980  2683.780029  2662.959961  2676.560059
# 5  2012-01-10  2704.419922  2712.500000  2694.330078  2702.500000
# 6  2012-01-11  2695.770020  2714.290039  2690.729980  2710.760010
# 7  2012-01-12  2716.870117  2726.429932  2697.320068  2724.699951
# 8  2012-01-13  2707.409912  2712.929932  2689.580078  2710.669922
# 9  2012-01-17  2736.340088  2742.729980  2721.030029  2728.080078
#
#      Adj Close      Volume
# 0  2648.719971  1636850000
# 1  2648.360107  1670530000
# 2  2669.860107  1836410000
# 3  2674.219971  1683090000
# 4  2676.560059  1768080000
# 5  2702.500000  1809500000
# 6  2710.760010  1699660000
# ...

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df3 = pd.merge(df,df1,on="Date", how="outer")

# %%
df3.head(10)
# Out:
#          Date  Open_x  High_x  Low_x  Close_x  Adj Close_x  Volume_x  \
# 0  2011-12-31   4.248   4.995  4.200    4.722        4.722    596240
# 1  2012-01-01   4.722   5.500  4.615    5.268        5.268    553045
# 2  2012-01-02   5.268   5.470  4.800    5.217        5.217    360357
# 3  2012-01-03   5.217   5.290  4.650    4.881        4.881    619170
# 4  2012-01-04   4.881   5.700  4.751    5.574        5.574    688717
# 5  2012-01-05   5.574   7.220  5.574    6.948        6.948   1130623
# 6  2012-01-06   6.948   7.210  6.126    6.697        6.697   1481327
# 7  2012-01-07   6.697   7.016  6.380    6.810        6.810    325053
# 8  2012-01-08   6.810   7.200  6.734    7.114        7.114    403151
# 9  2012-01-09   7.114   7.191  5.810    6.326        6.326    960592
#
#         Open_y       High_y        Low_y      Close_y  Adj Close_y  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# ...

# %%
df3.isnull().any()
# Out:
# Date           False
# Open_x         False
# High_x         False
# Low_x          False
# Close_x        False
# Adj Close_x    False
# Volume_x       False
# Open_y          True
# High_y          True
# Low_y           True
# Close_y         True
# Adj Close_y     True
# Volume_y        True
# dtype: bool

# %%
df3['Open_x'] = df3['Open_x'].astype("int")

# %%
df3.dtypes
# Out:
# Date            object
# Open_x           int32
# High_x         float64
# Low_x          float64
# Close_x        float64
# Adj Close_x    float64
# Volume_x         int64
# Open_y         float64
# High_y         float64
# Low_y          float64
# Close_y        float64
# Adj Close_y    float64
# Volume_y       float64
# dtype: object

# %%
df3['Open_y'] = df3['Open_y'].fillna(0)
df3['Open_y'] = df3['Open_y'].astype(int)

# %%
df3.dtypes
# Out:
# Date            object
# Open_x           int32
# High_x         float64
# Low_x          float64
# Close_x        float64
# Adj Close_x    float64
# Volume_x         int64
# Open_y           int32
# High_y         float64
# Low_y          float64
# Close_y        float64
# Adj Close_y    float64
# Volume_y         int64
# dtype: object

# %%
df3['Open_y'].pct_change()
df3['Open_y'] = df3['Open_y'].fillna(0)
df3['Open_y'] = df3['Open_y'].replace('NaN', 0)

# %%
df3['Open_x'].pct_change()
# Out:
# 0            NaN
# 1       0.000000
# 2       0.250000
# 3       0.000000
# 4      -0.200000
# 5       0.250000
# 6       0.200000
# 7       0.000000
# 8       0.000000
# 9       0.166667
# 10     -0.142857
# 11      0.000000
# 12      0.000000
# 13      0.000000
# 14      0.000000
# 15      0.000000
# 16      0.166667
# 17     -0.142857
# 18     -0.166667
# 19      0.000000
# 20      0.200000
# 21      0.000000
# 22      0.000000
# 23      0.000000
# 24      0.000000
# 25      0.000000
# 26     -0.166667
# 27      0.000000
# 28      0.000000
# 29      0.000000
#           ...
# 2737    0.107674
# 2738   -0.038122
# 2739   -0.093824
# 2740   -0.016529
# 2741    0.023888
# 2742    0.104851
# 2743   -0.068859
# 2744   -0.014611
# 2745    0.023197
# 2746    0.020092
# 2747    0.071640
# 2748    0.022040
# 2749   -0.037240
# 2750   -0.062485
# 2751    0.040025
# 2752   -0.036789
# 2753   -0.101998
# 2754    0.063309
# 2755   -0.131521
# 2756    0.028972
# 2757    0.097153
# ...

# %%
df3.head(10)
# Out:
#          Date  Open_x  High_x  Low_x  Close_x  Adj Close_x  Volume_x  Open_y  \
# 0  2011-12-31       4   4.995  4.200    4.722        4.722    596240       0
# 1  2012-01-01       4   5.500  4.615    5.268        5.268    553045       0
# 2  2012-01-02       5   5.470  4.800    5.217        5.217    360357       0
# 3  2012-01-03       5   5.290  4.650    4.881        4.881    619170    2657
# 4  2012-01-04       4   5.700  4.751    5.574        5.574    688717    2639
# 5  2012-01-05       5   7.220  5.574    6.948        6.948   1130623    2642
# 6  2012-01-06       6   7.210  6.126    6.697        6.697   1481327    2671
# 7  2012-01-07       6   7.016  6.380    6.810        6.810    325053       0
# 8  2012-01-08       6   7.200  6.734    7.114        7.114    403151       0
# 9  2012-01-09       7   7.191  5.810    6.326        6.326    960592    2682
#
#         High_y        Low_y      Close_y  Adj Close_y      Volume_y
# ...

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
df_x = df3['Open_y'].pct_change()

# %%
df_y = df3['Open_x'].pct_change()

# %%
df_x.describe()
# Out:
# count    2319.000000
# mean             inf
# std              NaN
# min        -1.000000
# 25%        -0.010269
# 50%         0.001332
# 75%         0.010750
# max              inf
# Name: Open_y, dtype: float64

# %%
df_y.describe()
# Out:
# count    2766.000000
# mean        0.005103
# std         0.086811
# min        -0.574713
# 25%        -0.009697
# 50%         0.000000
# 75%         0.017532
# max         3.392593
# Name: Open_x, dtype: float64

# %%
#reg=linear_model.LinearRegression()

# %%
#x_train,x_test,y_train,Y_test = train_test_split(df_x,df_y,test_size=0.2,random_state=4)

# %%
#reg.fit(x_train,y_train)

# %%
# %matplotlib inline
plt.scatter(df_x, df_y)
